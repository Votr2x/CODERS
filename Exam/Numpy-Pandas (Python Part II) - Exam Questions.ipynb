# %% [markdown]
# ### 1. Verilən URL-dən məlumatları `pandas` kitabxanasını istifadə edərək oxuyun. Daha sonra sütun adlarında və sütunların məzmununda mövcud ola biləcək problemləri analiz edin və uyğun funksiyalardan istifadə edərək bu problemləri aradan qaldırın.
#
# ---
#
# ### 1. Read the data from the provided URL using the `pandas` library. Then, analyze the columns for potential issues in their names or content. Use appropriate functions to resolve those issues.
#
# **URL:**
# https://archive.ics.uci.edu/ml/machine-learning-databases/00247/data_akbilgic.xlsx

# %%
import pandas as pd
import numpy as np
df = pd.read_excel("data_akbilgic.xlsx")
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### 2. Verilən DataFrame-in propertiləri və sütunlarının data type məlumatlarını çap edin.
#
# ---
#
# ### 2. Print the properties and information of the given DataFrame.

# %% [markdown]
# ### 3. Verilən DataFrame-də type-larla bağlı hər hansı problem varsa, bu problemi həll edin.
# ### Zaman datasında dəyişiklik tələb olunursa, bunu `lambda` funksiyası vasitəsilə edin.
#
# ---
#
# ### 3. If there are any issues with the data types in the DataFrame, try to resolve them.
# ### If modification of the date/time data is required, perform it using a `lambda` function.

# %% [markdown]
# ### 4. Verilən DataFrame-də sütunların seyrək (sparse) və ya tam (complete) olub-olmadığını analiz edin.
# ### Nəticələri izah edin və `null` dəyərləri Data Frame-dən silin.
#
# ---
#
# ### 4. Analyze the columns in the given DataFrame to determine whether they are sparse or complete.
# ### Provide your observations and remove the `null` values from the DataFrame.

# %% [markdown]
# ### 5. Verilən DataFrame-də eyni sütun adlarınız varsa, bu sütunları fərqləndirmək üçün adların sonuna müvafiq olaraq `TL_Based` və ya `USD_Based` əlavə edin və adları dəyişdirin.
#
# ---
#
# ### 5. If there are duplicate column names in the given DataFrame, differentiate them by appending `TL_Based` or `USD_Based` to their names, and update the column names accordingly.

# %% [markdown]
# ### 6. Verilən DataFrame-də outlier-ləri (anormal dəyərləri) tapmağa çalışın.
# #### - Outlier-lər olan sütunların adlarını çıxarın və bu sütunları boxplotlar vasitəsilə vizuallaşdırın.
# #### - Əgər outlier olan sütunlar məlumdursa, bu sütunlardakı dəyərləri 10000-ə vuraraq dəyişdirin və yenidən boxplot ilə vizuallaşdırın.
#
# ---
#
# ### 6. Attempt to identify the outliers in the given DataFrame.
# #### - Extract the names of the columns containing outliers and visualize them using boxplots.
# #### - If the columns with outliers are already known, multiply the values in these columns by 10000 and visualize the updated data again with boxplots.

# %% [markdown]
# ### 7. `Numpy` vasitəsilə yalnız 0-lardan (sıfırlardan) ibarət yeni bir sütun yaradın və bu sütunun adını **Zeros** olaraq təyin edin.
#
# ---
#
# ### 7. Using `Numpy`, create a new column consisting entirely of zeros and name this column **Zeros**.

# %% [markdown]
# ### 8. `ISE_TL_Based` sütunu ilə 100-ün dot product-ını hesablayın və nəticəni **Zeros** sütununa doldurun.
#
# ---
#
# ### 8. Compute the dot product of the `ISE_TL_Based` column with 100 and populate the **Zeros** column with the result.

# %% [markdown]
# ### 9. Yalnız `float64` tipli sütunların məlumat xüsusiyyətlərinə (data properties) baxın.
# #### - Əgər yeni bir sütunun miqyası (scale-i) fərqlidirsə, bu sütunlara normallaşdırma və ya standartlaşdırma üsulunu manual qaydada tətbiq edin.
# #### - Funksiyanı yazarkən `numpy` kitabxanasından istifadə edin.
#
# ---
#
# ### 9. Examine the data properties of the columns with a `float64` data type only.
# #### - If the scale of a new column differs, apply either normalization or standardization manually.
# #### - Use the `numpy` library when writing the function.

# %% [markdown]
# ### 10. Ən azı 10 hərfdən ibarət olan yeni bir sütun yaradın.
# #### - Sütunun adı **Label** olsun.
# #### - Bu sütundakı hərfləri rəqəmlərlə əvəz etmək üçün labeling metodunu tətbiq edin (funksiya şəklində).
# #### - Labeling nəticəsində alınan məlumatı `pandas DataFrame` formatına çevirərək əsas DataFrame ilə birləşdirin.
#
# ---
#
# ### 10. Create a new column consisting of at least 10 letters.
# #### - Name the column **Label**.
# #### - Apply a labeling method to replace the letters in this column with numbers (use a function).
# #### - Convert the result of the labeling into a `pandas DataFrame` and merge it with the main DataFrame.

# %% [markdown]
# ### 11. Son yaranan DataFrame-i `.csv` formatına çevirərək saxlayın və bu faylla birlikdə göndərin.
# #### - Bonus Point: Bütün addımları funksiyalar şəklində tərtib edərək implementasiya edin.
#
# ---
#
# ### 11. Convert the final DataFrame to a `.csv` file and send it along with this task.
# #### - Bonus Point: Implement all steps as separate functions.
