# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
# !pip install openpyxl

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

data2 = {
    'Employee_Name': ['John', 'Sara', 'Mike', 'Anna', 'Tom', 'Linda', 'Robert', 'John', 'Chris', 'Nina'],
    'Age_Years': [27, None, 34, 29, 41, None, 36, 30, 28, 33],
    'Hire_Date': ['2021-12-01', '03/01/2022', None, '2022.04.15', 'invalid', '2022-06-10', '2022/07/25', None, '2023-01-20', '15-03-2023'],
    'Salary(USD)': [48000, 52000, 61000, None, 70000, 58000, None, 49000, 51000, 62000],
    'Dept': ['Sales', 'IT', None, 'Finance', 'Sales', 'IT', 'Finance', 'Finance', None, 'Sales'],
    'Perf_Score': [88, 91, None, 85, 79, 90, 92, None, 86, 84],
    'Monthly_Spend': [2200, 2500, None, 2700, 2600, 2400, 2800, 3000, None, 2650],
    'Extra_Info': [np.nan, 1, np.nan, 2, np.nan, np.nan, 3, np.nan, np.nan, np.nan],
    'Level': ['Junior', 'Senior', 'Mid', 'Junior', None, 'Senior', 'Mid', 'Junior', 'Senior', None]
}

df = pd.DataFrame(data2)
df
# Out:
#   Employee_Name  Age_Years   Hire_Date  Salary(USD)     Dept  Perf_Score  \
# 0          John       27.0  2021-12-01      48000.0    Sales        88.0
# 1          Sara        NaN  03/01/2022      52000.0       IT        91.0
# 2          Mike       34.0        None      61000.0     None         NaN
# 3          Anna       29.0  2022.04.15          NaN  Finance        85.0
# 4           Tom       41.0     invalid      70000.0    Sales        79.0
# 5         Linda        NaN  2022-06-10      58000.0       IT        90.0
# 6        Robert       36.0  2022/07/25          NaN  Finance        92.0
# 7          John       30.0        None      49000.0  Finance         NaN
# 8         Chris       28.0  2023-01-20      51000.0     None        86.0
# 9          Nina       33.0  15-03-2023      62000.0    Sales        84.0
#
#    Monthly_Spend  Extra_Info   Level
# 0         2200.0         NaN  Junior
# 1         2500.0         1.0  Senior
# 2            NaN         NaN     Mid
# ...

# %%
# 1.Sütun adlarındakı boşluqları və xüsusi simvolları təmizləyin. Eyni zamanda, bütün sütun adlarını kiçik hərflərə çevirin
# və səliqəli bir formata salın.

# %%
# 2. DataFrame-dəki hər bir sütunun data tipini, boş dəyərlərin cəmini və unikal dəyərlərin sayını çap edin.

# %%
# 3. DataFrame-də hansı sütunların sparse və ya complete olduğunu təyin edin.

# %%
# 4. salary sütununda outlier-ləri IQR metodundan istifadə edərək təyin edin və onları DataFrame-dən çıxarın.

# %%
# 5. salary sütununda outlier-ləri boxplot ilə göstərin.

# %%
# 6. DataFrame-də yalnız float64 tipində olan sütunların orta, maksimum və minimum dəyərlərini tapın.

# %%
# 7. salary sütununu normallaşdırın və standartlaşdırın. Normalizasiya və standartlaşdırma üçün funksiyalar yazın.

# %%
# 8. categorical sütununu rəqəmlərlə əvəz edin və bu məqsədlə LabelEncoder istifadə edin.
