# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('german_credit_data.csv')
print(df.head())
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
df = pd.read_csv('german_credit_data.csv')
result = df.groupby('Purpose')['Credit amount'].apply(
    lambda x: (np.log((x.max() - x.min()) / 2) ** 2)
)

print(result)
# Out:
# Purpose
# business               80.009646
# car                    79.188203
# domestic appliances    56.377768
# education              76.073455
# furniture/equipment    78.069942
# radio/TV               79.985134
# repairs                75.009005
# vacation/others        82.137965
# Name: Credit amount, dtype: float64
